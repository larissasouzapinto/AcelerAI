# %% [markdown]
# ##### Target variables are:
#     1. Tool wear detection
#     2. Detection of inadequate clamping- "Passed visual inspection"
#     3. Machining finalised

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_12.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/test_artifact.jpg
# /kaggle/input/tool-wear-detection-in-cnc-mill/train.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_15.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_06.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_10.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_03.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_16.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_14.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/README.txt
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_17.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_11.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_08.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_09.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_01.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_05.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_18.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_13.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_04.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_07.csv
# /kaggle/input/tool-wear-detection-in-cnc-mill/experiment_02.csv

# %% [markdown]
# > ## 1. Load Data

# %%
main_df=pd.read_csv('/kaggle/input/tool-wear-detection-in-cnc-mill/train.csv')
main_df=main_df.fillna('no')
main_df.head()
# Out:
#    No material  feedrate  clamp_pressure tool_condition machining_finalized  \
# 0   1      wax         6             4.0         unworn                 yes
# 1   2      wax        20             4.0         unworn                 yes
# 2   3      wax         6             3.0         unworn                 yes
# 3   4      wax         6             2.5         unworn                  no
# 4   5      wax        20             3.0         unworn                  no
#
#   passed_visual_inspection
# 0                      yes
# 1                      yes
# 2                      yes
# 3                       no
# 4                       no

# %%
import glob
#set working directory
os.chdir('/kaggle/input')

# %% [markdown]
# ### Creating the data frame

# %%
files = list()

for i in range(1,19):
    exp_number = '0' + str(i) if i < 10 else str(i)
    file = pd.read_csv("/kaggle/input/tool-wear-detection-in-cnc-mill/experiment_{}.csv".format(exp_number))
    row = main_df[main_df['No'] == i]
    
     #add experiment settings to features
    file['feedrate']=row.iloc[0]['feedrate']
    file['clamp_pressure']=row.iloc[0]['clamp_pressure']
    
    # Having label as 'tool_conidtion'
    
    file['label'] = 1 if row.iloc[0]['tool_condition'] == 'worn' else 0
    files.append(file)
df = pd.concat(files, ignore_index = True)
df.head()
# Out:
#    X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
# 3              194.0              -18.0                   0.00
# 4              193.0              -17.9                 -18.80
#
#    X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6             -358.000000
# 2               196.0               -17.9               -0.000095
# 3               194.0               -17.9               -0.000095
# 4               192.0               -17.9                0.000095
#
#    X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  X1_OutputVoltage  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
# 3               -6.11           0.1300             327.0             30.30
# 4               -5.70           0.1140             328.0             30.50
#
#    ...  S1_OutputVoltage  S1_OutputPower  S1_SystemInertia  \
# 0  ...               0.0    6.960000e-07              12.0
# 1  ...               0.0   -5.270000e-07              12.0
# 2  ...               0.0    9.100000e-07              12.0
# 3  ...               0.0    1.070000e-06              12.0
# 4  ...               0.0    1.960000e-06              12.0
#
#    M1_CURRENT_PROGRAM_NUMBER  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 0                        1.0                 0.0                 50.0
# 1                        1.0                 4.0                 50.0
# 2                        1.0                 7.0                 50.0
# 3                        1.0                 7.0                 50.0
# 4                        1.0                 7.0                 50.0
#
#    Machining_Process  feedrate  clamp_pressure  label
# 0           Starting         6             4.0      0
# 1               Prep         6             4.0      0
# 2               Prep         6             4.0      0
# 3               Prep         6             4.0      0
# 4               Prep         6             4.0      0
#
# [5 rows x 51 columns]

# %%
df.shape
# Out:
# (25286, 51)

# %%
df.dtypes
# Out:
# X1_ActualPosition            float64
# X1_ActualVelocity            float64
# X1_ActualAcceleration        float64
# X1_CommandPosition           float64
# X1_CommandVelocity           float64
# X1_CommandAcceleration       float64
# X1_CurrentFeedback           float64
# X1_DCBusVoltage              float64
# X1_OutputCurrent             float64
# X1_OutputVoltage             float64
# X1_OutputPower               float64
# Y1_ActualPosition            float64
# Y1_ActualVelocity            float64
# Y1_ActualAcceleration        float64
# Y1_CommandPosition           float64
# Y1_CommandVelocity           float64
# Y1_CommandAcceleration       float64
# Y1_CurrentFeedback           float64
# Y1_DCBusVoltage              float64
# Y1_OutputCurrent             float64
# Y1_OutputVoltage             float64
# Y1_OutputPower               float64
# Z1_ActualPosition            float64
# Z1_ActualVelocity            float64
# Z1_ActualAcceleration        float64
# Z1_CommandPosition           float64
# Z1_CommandVelocity           float64
# Z1_CommandAcceleration       float64
# Z1_CurrentFeedback           float64
# Z1_DCBusVoltage              float64
# Z1_OutputCurrent             float64
# Z1_OutputVoltage             float64
# S1_ActualPosition            float64
# S1_ActualVelocity            float64
# S1_ActualAcceleration        float64
# S1_CommandPosition           float64
# S1_CommandVelocity           float64
# S1_CommandAcceleration       float64
# S1_CurrentFeedback           float64
# S1_DCBusVoltage              float64
# S1_OutputCurrent             float64
# S1_OutputVoltage             float64
# S1_OutputPower               float64
# S1_SystemInertia             float64
# M1_CURRENT_PROGRAM_NUMBER    float64
# M1_sequence_number           float64
# M1_CURRENT_FEEDRATE          float64
# Machining_Process             object
# feedrate                       int64
# clamp_pressure               float64
# label                          int64
# dtype: object

# %%
# Convert 'Machining_process' into numerical values
pro={'Layer 1 Up':1,'Repositioning':2,'Layer 2 Up':3,'Layer 2 Up':4,'Layer 1 Down':5,'End':6,'Layer 2 Down':7,'Layer 3 Down':8,'Prep':9,'end':10,'Starting':11}

data=[df]

for dataset in data:
    dataset['Machining_Process']=dataset['Machining_Process'].map(pro)

# %%
df=df.drop(['Z1_CurrentFeedback','Z1_DCBusVoltage','Z1_OutputCurrent','Z1_OutputVoltage','S1_SystemInertia'],axis=1)

# %%
corm=df.corr()
corm
# Out:
#                            X1_ActualPosition  X1_ActualVelocity  \
# X1_ActualPosition                   1.000000          -0.027925
# X1_ActualVelocity                  -0.027925           1.000000
# X1_ActualAcceleration              -0.015813           0.042899
# X1_CommandPosition                  0.999897          -0.025593
# X1_CommandVelocity                 -0.030200           0.994736
# X1_CommandAcceleration             -0.022721          -0.054833
# X1_CurrentFeedback                  0.075901           0.656705
# X1_DCBusVoltage                    -0.522043          -0.007850
# X1_OutputCurrent                    0.349605          -0.057059
# X1_OutputVoltage                   -0.290193           0.063614
# X1_OutputPower                     -0.080891           0.190011
# Y1_ActualPosition                   0.888528           0.012624
# Y1_ActualVelocity                  -0.102731           0.296476
# Y1_ActualAcceleration              -0.008712          -0.013794
# Y1_CommandPosition                  0.888413           0.013041
# Y1_CommandVelocity                 -0.103280           0.297780
# Y1_CommandAcceleration             -0.005101           0.004757
# Y1_CurrentFeedback                 -0.131606          -0.038403
# Y1_DCBusVoltage                    -0.341243          -0.056749
# Y1_OutputCurrent                    0.500171          -0.022695
# Y1_OutputVoltage                   -0.124481          -0.102756
# Y1_OutputPower                      0.033841          -0.085863
# Z1_ActualPosition                   0.880043           0.006283
# Z1_ActualVelocity                  -0.109356           0.237343
# Z1_ActualAcceleration              -0.005602          -0.002692
# Z1_CommandPosition                  0.879920           0.006709
# Z1_CommandVelocity                 -0.109685           0.237102
# Z1_CommandAcceleration             -0.006820          -0.004960
# S1_ActualPosition                  -0.103477           0.009144
# S1_ActualVelocity                  -0.663605           0.064024
# S1_ActualAcceleration               0.001704          -0.020281
# S1_CommandPosition                 -0.103584           0.009154
# S1_CommandVelocity                 -0.644630           0.062270
# S1_CommandAcceleration             -0.028627          -0.055246
# S1_CurrentFeedback                 -0.593782           0.041381
# S1_DCBusVoltage                    -0.613660           0.041160
# S1_OutputCurrent                    0.530134          -0.035890
# S1_OutputVoltage                   -0.644873           0.061762
# S1_OutputPower                     -0.626264           0.048899
# M1_CURRENT_PROGRAM_NUMBER           0.016684           0.002800
# M1_sequence_number                 -0.408106           0.020850
# M1_CURRENT_FEEDRATE                 0.436281          -0.021601
# Machining_Process                   0.009185          -0.017290
# feedrate                            0.453219          -0.007987
# clamp_pressure                      0.108508          -0.017314
# label                              -0.091920          -0.008353
#
#                            X1_ActualAcceleration  X1_CommandPosition  \
# X1_ActualPosition                      -0.015813            0.999897
# X1_ActualVelocity                       0.042899           -0.025593
# X1_ActualAcceleration                   1.000000           -0.015834
# X1_CommandPosition                     -0.015834            1.000000
# X1_CommandVelocity                      0.082456           -0.027861
# X1_CommandAcceleration                  0.389891           -0.022636
# X1_CurrentFeedback                      0.147840            0.077469
# X1_DCBusVoltage                         0.078077           -0.522235
# X1_OutputCurrent                       -0.016064            0.349688
# X1_OutputVoltage                        0.046832           -0.290381
# X1_OutputPower                          0.107488           -0.080774
# Y1_ActualPosition                      -0.005514            0.888720
# Y1_ActualVelocity                       0.004232           -0.102159
# Y1_ActualAcceleration                  -0.069679           -0.008735
# Y1_CommandPosition                     -0.005500            0.888606
# Y1_CommandVelocity                      0.000900           -0.102704
# Y1_CommandAcceleration                 -0.042824           -0.005124
# Y1_CurrentFeedback                     -0.000710           -0.131647
# Y1_DCBusVoltage                         0.017137           -0.341377
# Y1_OutputCurrent                       -0.000308            0.500264
# Y1_OutputVoltage                        0.009535           -0.124810
# Y1_OutputPower                          0.020056            0.033501
# Z1_ActualPosition                       0.001489            0.880197
# Z1_ActualVelocity                       0.007526           -0.108794
# Z1_ActualAcceleration                   0.008779           -0.005579
# Z1_CommandPosition                      0.001510            0.880076
# Z1_CommandVelocity                      0.008814           -0.109122
# Z1_CommandAcceleration                  0.017044           -0.006817
# S1_ActualPosition                      -0.004451           -0.103486
# S1_ActualVelocity                      -0.006438           -0.663566
# S1_ActualAcceleration                  -0.013959            0.001694
# S1_CommandPosition                     -0.004453           -0.103592
# S1_CommandVelocity                     -0.006917           -0.644593
# S1_CommandAcceleration                 -0.012156           -0.028754
# S1_CurrentFeedback                     -0.006727           -0.593789
# S1_DCBusVoltage                        -0.008171           -0.613666
# S1_OutputCurrent                        0.003505            0.530155
# S1_OutputVoltage                       -0.007081           -0.644838
# S1_OutputPower                         -0.002979           -0.626251
# M1_CURRENT_PROGRAM_NUMBER               0.001840            0.016690
# M1_sequence_number                     -0.007341           -0.408173
# M1_CURRENT_FEEDRATE                     0.015675            0.436145
# Machining_Process                      -0.013923            0.009137
# feedrate                                0.022708            0.453153
# clamp_pressure                          0.011408            0.108510
# label                                   0.004147           -0.092029
#
#                            X1_CommandVelocity  X1_CommandAcceleration  \
# X1_ActualPosition                   -0.030200               -0.022721
# X1_ActualVelocity                    0.994736               -0.054833
# X1_ActualAcceleration                0.082456                0.389891
# X1_CommandPosition                  -0.027861               -0.022636
# X1_CommandVelocity                   1.000000                0.039428
# X1_CommandAcceleration               0.039428                1.000000
# X1_CurrentFeedback                   0.676604                0.126885
# X1_DCBusVoltage                     -0.001226                0.059561
# X1_OutputCurrent                    -0.058431               -0.010022
# X1_OutputVoltage                     0.065110                0.016314
# X1_OutputPower                       0.198001                0.070454
# Y1_ActualPosition                    0.012194               -0.004594
# Y1_ActualVelocity                    0.296302               -0.002265
# Y1_ActualAcceleration               -0.018416               -0.051468
# Y1_CommandPosition                   0.012610               -0.004601
# Y1_CommandVelocity                   0.296830               -0.009045
# Y1_CommandAcceleration              -0.002568               -0.069560
# Y1_CurrentFeedback                  -0.039376               -0.007101
# Y1_DCBusVoltage                     -0.053593                0.022896
# Y1_OutputCurrent                    -0.023493               -0.002396
# Y1_OutputVoltage                    -0.101989                0.002139
# Y1_OutputPower                      -0.085068                0.002131
# Z1_ActualPosition                    0.005361               -0.004996
# Z1_ActualVelocity                    0.236578               -0.002825
# Z1_ActualAcceleration               -0.000358                0.020034
# Z1_CommandPosition                   0.005786               -0.004998
# Z1_CommandVelocity                   0.236534               -0.000946
# Z1_CommandAcceleration              -0.001801                0.030569
# S1_ActualPosition                    0.008275               -0.005643
# S1_ActualVelocity                    0.064718                0.003370
# S1_ActualAcceleration               -0.020636               -0.004164
# S1_CommandPosition                   0.008285               -0.005645
# S1_CommandVelocity                   0.063127                0.004543
# S1_CommandAcceleration              -0.056859               -0.017179
# S1_CurrentFeedback                   0.041457               -0.002499
# S1_DCBusVoltage                      0.041234               -0.002751
# S1_OutputCurrent                    -0.036472               -0.002754
# S1_OutputVoltage                     0.062592                0.004140
# S1_OutputPower                       0.049627                0.003663
# M1_CURRENT_PROGRAM_NUMBER            0.003463                0.007051
# M1_sequence_number                   0.020269               -0.009969
# M1_CURRENT_FEEDRATE                 -0.021655                0.004968
# Machining_Process                   -0.017216               -0.005226
# feedrate                            -0.006797                0.011360
# clamp_pressure                      -0.017402                0.000844
# label                               -0.008909               -0.005586
#
#                            X1_CurrentFeedback  X1_DCBusVoltage  \
# X1_ActualPosition                    0.075901        -0.522043
# X1_ActualVelocity                    0.656705        -0.007850
# X1_ActualAcceleration                0.147840         0.078077
# X1_CommandPosition                   0.077469        -0.522235
# X1_CommandVelocity                   0.676604        -0.001226
# X1_CommandAcceleration               0.126885         0.059561
# X1_CurrentFeedback                   1.000000        -0.013091
# X1_DCBusVoltage                     -0.013091         1.000000
# X1_OutputCurrent                    -0.076092        -0.438586
# X1_OutputVoltage                    -0.009337         0.759302
# X1_OutputPower                       0.052380         0.594746
# Y1_ActualPosition                    0.045305        -0.511034
# Y1_ActualVelocity                    0.059434        -0.125787
# Y1_ActualAcceleration               -0.003931        -0.016112
# Y1_CommandPosition                   0.045373        -0.511277
# Y1_CommandVelocity                   0.059384        -0.128203
# Y1_CommandAcceleration              -0.002817        -0.020299
# Y1_CurrentFeedback                  -0.250374        -0.068150
# Y1_DCBusVoltage                      0.001217         0.417941
# Y1_OutputCurrent                    -0.047163        -0.532617
# Y1_OutputVoltage                    -0.045868         0.336586
# Y1_OutputPower                      -0.064431         0.252652
# Z1_ActualPosition                   -0.028231        -0.607461
# Z1_ActualVelocity                    0.069257        -0.109782
# Z1_ActualAcceleration                0.001322        -0.002960
# Z1_CommandPosition                  -0.028110        -0.607715
# Z1_CommandVelocity                   0.069609        -0.110526
# Z1_CommandAcceleration               0.003524        -0.010767
# S1_ActualPosition                    0.006330         0.089204
# S1_ActualVelocity                    0.104575         0.551578
# S1_ActualAcceleration               -0.009098         0.014161
# S1_CommandPosition                   0.006338         0.089298
# S1_CommandVelocity                   0.108957         0.551655
# S1_CommandAcceleration              -0.031077         0.012078
# S1_CurrentFeedback                   0.090606         0.509968
# S1_DCBusVoltage                      0.091564         0.525696
# S1_OutputCurrent                    -0.078464        -0.520377
# S1_OutputVoltage                     0.108385         0.551953
# S1_OutputPower                       0.097094         0.542717
# M1_CURRENT_PROGRAM_NUMBER            0.000687        -0.014266
# M1_sequence_number                   0.047524         0.342302
# M1_CURRENT_FEEDRATE                 -0.107711        -0.420468
# Machining_Process                    0.003780         0.009398
# feedrate                            -0.015001        -0.265393
# clamp_pressure                      -0.013569        -0.044318
# label                               -0.020931         0.076864
#
#                            X1_OutputCurrent  X1_OutputVoltage  ...  \
# X1_ActualPosition                  0.349605         -0.290193  ...
# X1_ActualVelocity                 -0.057059          0.063614  ...
# X1_ActualAcceleration             -0.016064          0.046832  ...
# X1_CommandPosition                 0.349688         -0.290381  ...
# X1_CommandVelocity                -0.058431          0.065110  ...
# X1_CommandAcceleration            -0.010022          0.016314  ...
# X1_CurrentFeedback                -0.076092         -0.009337  ...
# X1_DCBusVoltage                   -0.438586          0.759302  ...
# X1_OutputCurrent                   1.000000         -0.424382  ...
# X1_OutputVoltage                  -0.424382          1.000000  ...
# X1_OutputPower                    -0.325839          0.879473  ...
# Y1_ActualPosition                  0.360896         -0.293291  ...
# Y1_ActualVelocity                 -0.061096         -0.215949  ...
# Y1_ActualAcceleration             -0.013929         -0.008863  ...
# Y1_CommandPosition                 0.360820         -0.293693  ...
# Y1_CommandVelocity                -0.063176         -0.216450  ...
# Y1_CommandAcceleration            -0.022194         -0.002652  ...
# Y1_CurrentFeedback                -0.012352         -0.104785  ...
# Y1_DCBusVoltage                   -0.316781          0.351959  ...
# Y1_OutputCurrent                   0.798668         -0.433393  ...
# Y1_OutputVoltage                  -0.228800          0.479643  ...
# Y1_OutputPower                    -0.108162          0.486099  ...
# Z1_ActualPosition                  0.492225         -0.333496  ...
# Z1_ActualVelocity                 -0.103984         -0.230706  ...
# Z1_ActualAcceleration              0.002796         -0.006334  ...
# Z1_CommandPosition                 0.492080         -0.333940  ...
# Z1_CommandVelocity                -0.103487         -0.230709  ...
# Z1_CommandAcceleration             0.004593         -0.001494  ...
# S1_ActualPosition                 -0.093464          0.067137  ...
# S1_ActualVelocity                 -0.587531          0.295468  ...
# S1_ActualAcceleration             -0.029882         -0.004325  ...
# S1_CommandPosition                -0.093562          0.067190  ...
# S1_CommandVelocity                -0.596049          0.298947  ...
# S1_CommandAcceleration            -0.093317          0.024257  ...
# S1_CurrentFeedback                -0.578629          0.289259  ...
# S1_DCBusVoltage                   -0.602693          0.299153  ...
# S1_OutputCurrent                   0.727152         -0.303065  ...
# S1_OutputVoltage                  -0.599540          0.300806  ...
# S1_OutputPower                    -0.611948          0.307722  ...
# M1_CURRENT_PROGRAM_NUMBER          0.043361         -0.004949  ...
# M1_sequence_number                -0.367667          0.170238  ...
# M1_CURRENT_FEEDRATE                0.382719         -0.133161  ...
# Machining_Process                  0.027348         -0.004166  ...
# feedrate                          -0.172817          0.027534  ...
# clamp_pressure                    -0.308918          0.057796  ...
# label                             -0.080973          0.075167  ...
#
#                            S1_OutputCurrent  S1_OutputVoltage  S1_OutputPower  \
# X1_ActualPosition                  0.530134         -0.644873       -0.626264
# X1_ActualVelocity                 -0.035890          0.061762        0.048899
# X1_ActualAcceleration              0.003505         -0.007081       -0.002979
# X1_CommandPosition                 0.530155         -0.644838       -0.626251
# X1_CommandVelocity                -0.036472          0.062592        0.049627
# X1_CommandAcceleration            -0.002754          0.004140        0.003663
# X1_CurrentFeedback                -0.078464          0.108385        0.097094
# X1_DCBusVoltage                   -0.520377          0.551953        0.542717
# X1_OutputCurrent                   0.727152         -0.599540       -0.611948
# X1_OutputVoltage                  -0.303065          0.300806        0.307722
# X1_OutputPower                    -0.139494          0.078561        0.091718
# Y1_ActualPosition                  0.563234         -0.667213       -0.650591
# Y1_ActualVelocity                 -0.100977          0.131152        0.128237
# Y1_ActualAcceleration             -0.002658          0.011403        0.012109
# Y1_CommandPosition                 0.563096         -0.667051       -0.650431
# Y1_CommandVelocity                -0.102553          0.131950        0.129413
# Y1_CommandAcceleration            -0.012942          0.008856        0.011653
# Y1_CurrentFeedback                -0.023332          0.032602        0.035763
# Y1_DCBusVoltage                   -0.382166          0.445700        0.425816
# Y1_OutputCurrent                   0.753770         -0.661117       -0.664805
# Y1_OutputVoltage                  -0.150910          0.148863        0.144871
# Y1_OutputPower                     0.026954         -0.087345       -0.081706
# Z1_ActualPosition                  0.721829         -0.879985       -0.853252
# Z1_ActualVelocity                 -0.104644          0.112801        0.107966
# Z1_ActualAcceleration             -0.015347         -0.003422       -0.000739
# Z1_CommandPosition                 0.721706         -0.879862       -0.853135
# Z1_CommandVelocity                -0.104377          0.112708        0.107935
# Z1_CommandAcceleration            -0.000483         -0.001609        0.000207
# S1_ActualPosition                 -0.114968          0.164093        0.151704
# S1_ActualVelocity                 -0.810087          0.989567        0.954001
# S1_ActualAcceleration             -0.105187          0.013984       -0.052813
# S1_CommandPosition                -0.115108          0.164252        0.151857
# S1_CommandVelocity                -0.818281          0.999298        0.964139
# S1_CommandAcceleration            -0.125598         -0.017857        0.107789
# S1_CurrentFeedback                -0.789409          0.901427        0.945713
# S1_DCBusVoltage                   -0.823662          0.931075        0.977768
# S1_OutputCurrent                   1.000000         -0.818261       -0.835342
# S1_OutputVoltage                  -0.818261          1.000000        0.965145
# S1_OutputPower                    -0.835342          0.965145        1.000000
# M1_CURRENT_PROGRAM_NUMBER          0.044459         -0.014263       -0.013744
# M1_sequence_number                -0.514671          0.643384        0.613410
# M1_CURRENT_FEEDRATE                0.652483         -0.834502       -0.802810
# Machining_Process                  0.023925         -0.001778       -0.009321
# feedrate                           0.256529         -0.474265       -0.438656
# clamp_pressure                    -0.038593         -0.112622       -0.089017
# label                             -0.054738          0.019141        0.017337
#
#                            M1_CURRENT_PROGRAM_NUMBER  M1_sequence_number  \
# X1_ActualPosition                           0.016684           -0.408106
# X1_ActualVelocity                           0.002800            0.020850
# X1_ActualAcceleration                       0.001840           -0.007341
# X1_CommandPosition                          0.016690           -0.408173
# X1_CommandVelocity                          0.003463            0.020269
# X1_CommandAcceleration                      0.007051           -0.009969
# X1_CurrentFeedback                          0.000687            0.047524
# X1_DCBusVoltage                            -0.014266            0.342302
# X1_OutputCurrent                            0.043361           -0.367667
# X1_OutputVoltage                           -0.004949            0.170238
# X1_OutputPower                             -0.000638            0.031594
# Y1_ActualPosition                           0.016517           -0.433552
# Y1_ActualVelocity                          -0.004865            0.044756
# Y1_ActualAcceleration                       0.001396            0.010114
# Y1_CommandPosition                          0.016505           -0.433520
# Y1_CommandVelocity                         -0.004944            0.045016
# Y1_CommandAcceleration                     -0.000584            0.002032
# Y1_CurrentFeedback                         -0.005404           -0.046209
# Y1_DCBusVoltage                            -0.007883            0.288636
# Y1_OutputCurrent                            0.076555           -0.403990
# Y1_OutputVoltage                           -0.000743            0.088736
# Y1_OutputPower                              0.002600           -0.057268
# Z1_ActualPosition                           0.017156           -0.580224
# Z1_ActualVelocity                           0.001603            0.086431
# Z1_ActualAcceleration                       0.002075            0.002857
# Z1_CommandPosition                          0.017161           -0.580120
# Z1_CommandVelocity                          0.001857            0.086342
# Z1_CommandAcceleration                      0.003634            0.000055
# S1_ActualPosition                          -0.030746            0.126999
# S1_ActualVelocity                          -0.013207            0.642461
# S1_ActualAcceleration                      -0.002558            0.011036
# S1_CommandPosition                         -0.030748            0.127119
# S1_CommandVelocity                         -0.014136            0.644489
# S1_CommandAcceleration                     -0.004275           -0.051561
# S1_CurrentFeedback                         -0.017837            0.564068
# S1_DCBusVoltage                            -0.014473            0.586846
# S1_OutputCurrent                            0.044459           -0.514671
# S1_OutputVoltage                           -0.014263            0.643384
# S1_OutputPower                             -0.013744            0.613410
# M1_CURRENT_PROGRAM_NUMBER                   1.000000           -0.010649
# M1_sequence_number                         -0.010649            1.000000
# M1_CURRENT_FEEDRATE                         0.016810           -0.542391
# Machining_Process                          -0.000514            0.034498
# feedrate                                    0.020581           -0.331306
# clamp_pressure                              0.010117           -0.067312
# label                                      -0.010390            0.015939
#
#                            M1_CURRENT_FEEDRATE  Machining_Process  feedrate  \
# X1_ActualPosition                     0.436281           0.009185  0.453219
# X1_ActualVelocity                    -0.021601          -0.017290 -0.007987
# X1_ActualAcceleration                 0.015675          -0.013923  0.022708
# X1_CommandPosition                    0.436145           0.009137  0.453153
# X1_CommandVelocity                   -0.021655          -0.017216 -0.006797
# X1_CommandAcceleration                0.004968          -0.005226  0.011360
# X1_CurrentFeedback                   -0.107711           0.003780 -0.015001
# X1_DCBusVoltage                      -0.420468           0.009398 -0.265393
# X1_OutputCurrent                      0.382719           0.027348 -0.172817
# X1_OutputVoltage                     -0.133161          -0.004166  0.027534
# X1_OutputPower                        0.071097          -0.017366  0.189350
# Y1_ActualPosition                     0.459484          -0.003122  0.455543
# Y1_ActualVelocity                    -0.155832          -0.058045 -0.013989
# Y1_ActualAcceleration                -0.006114           0.006975  0.010048
# Y1_CommandPosition                    0.459270          -0.003169  0.455564
# Y1_CommandVelocity                   -0.155391          -0.058878 -0.011152
# Y1_CommandAcceleration                0.003365          -0.001752  0.029994
# Y1_CurrentFeedback                   -0.033132          -0.072719 -0.005756
# Y1_DCBusVoltage                      -0.356226           0.002879 -0.208362
# Y1_OutputCurrent                      0.486160           0.017245  0.106989
# Y1_OutputVoltage                     -0.050167           0.007694  0.026021
# Y1_OutputPower                        0.167596           0.006555  0.160583
# Z1_ActualPosition                     0.698981          -0.008575  0.524826
# Z1_ActualVelocity                    -0.037436          -0.028310 -0.007310
# Z1_ActualAcceleration                 0.003184           0.008862  0.010045
# Z1_CommandPosition                    0.698982          -0.008628  0.524860
# Z1_CommandVelocity                   -0.037310          -0.028346 -0.006987
# Z1_CommandAcceleration                0.003258           0.001298  0.005692
# S1_ActualPosition                    -0.128359           0.021690 -0.099861
# S1_ActualVelocity                    -0.822984           0.002933 -0.477213
# S1_ActualAcceleration                -0.024511          -0.006443 -0.011842
# S1_CommandPosition                   -0.128489           0.021687 -0.099933
# S1_CommandVelocity                   -0.835581           0.000143 -0.477036
# S1_CommandAcceleration                0.001047          -0.024233  0.025893
# S1_CurrentFeedback                   -0.755658          -0.008007 -0.413673
# S1_DCBusVoltage                      -0.777562          -0.012237 -0.421616
# S1_OutputCurrent                      0.652483           0.023925  0.256529
# S1_OutputVoltage                     -0.834502          -0.001778 -0.474265
# S1_OutputPower                       -0.802810          -0.009321 -0.438656
# M1_CURRENT_PROGRAM_NUMBER             0.016810          -0.000514  0.020581
# M1_sequence_number                   -0.542391           0.034498 -0.331306
# M1_CURRENT_FEEDRATE                   1.000000          -0.015077  0.530966
# Machining_Process                    -0.015077           1.000000  0.013713
# feedrate                              0.530966           0.013713  1.000000
# clamp_pressure                        0.224498          -0.032169  0.382278
# label                                 0.061106           0.061682  0.049609
#
#                            clamp_pressure     label
# X1_ActualPosition                0.108508 -0.091920
# X1_ActualVelocity               -0.017314 -0.008353
# X1_ActualAcceleration            0.011408  0.004147
# X1_CommandPosition               0.108510 -0.092029
# X1_CommandVelocity              -0.017402 -0.008909
# X1_CommandAcceleration           0.000844 -0.005586
# X1_CurrentFeedback              -0.013569 -0.020931
# X1_DCBusVoltage                 -0.044318  0.076864
# X1_OutputCurrent                -0.308918 -0.080973
# X1_OutputVoltage                 0.057796  0.075167
# X1_OutputPower                   0.091099  0.058509
# Y1_ActualPosition                0.107970 -0.090862
# Y1_ActualVelocity               -0.025709 -0.012806
# Y1_ActualAcceleration            0.003793  0.000859
# Y1_CommandPosition               0.107963 -0.090920
# Y1_CommandVelocity              -0.023913 -0.012421
# Y1_CommandAcceleration           0.018498  0.004688
# Y1_CurrentFeedback              -0.009415 -0.004996
# Y1_DCBusVoltage                 -0.043210  0.050999
# Y1_OutputCurrent                -0.153976 -0.176805
# Y1_OutputVoltage                 0.032035  0.056277
# Y1_OutputPower                   0.060229  0.045418
# Z1_ActualPosition                0.128033 -0.064627
# Z1_ActualVelocity               -0.014813 -0.008173
# Z1_ActualAcceleration            0.003252 -0.001953
# Z1_CommandPosition               0.128035 -0.064638
# Z1_CommandVelocity              -0.014528 -0.008065
# Z1_CommandAcceleration           0.004878  0.000666
# S1_ActualPosition               -0.095431  0.007011
# S1_ActualVelocity               -0.118905  0.021777
# S1_ActualAcceleration           -0.005658 -0.011138
# S1_CommandPosition              -0.095450  0.007017
# S1_CommandVelocity              -0.117498  0.019994
# S1_CommandAcceleration           0.003740  0.002797
# S1_CurrentFeedback              -0.092715  0.022222
# S1_DCBusVoltage                 -0.086143  0.018190
# S1_OutputCurrent                -0.038593 -0.054738
# S1_OutputVoltage                -0.112622  0.019141
# S1_OutputPower                  -0.089017  0.017337
# M1_CURRENT_PROGRAM_NUMBER        0.010117 -0.010390
# M1_sequence_number              -0.067312  0.015939
# M1_CURRENT_FEEDRATE              0.224498  0.061106
# Machining_Process               -0.032169  0.061682
# feedrate                         0.382278  0.049609
# clamp_pressure                   1.000000  0.091851
# label                            0.091851  1.000000
#
# [46 rows x 46 columns]

# %%
#checking the relationship between the variables by applying the correlation 
plt.figure(figsize=(30, 25))
p = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## 2. Building ML Model

# %%
X=df.drop(['label','Machining_Process'],axis=1)
Y=df['label']
print('The dimension of X table is: ',X.shape,'\n')
print('The dimension of Y table is: ', Y.shape)
# Out:
# The dimension of X table is:  (25286, 44)
#
# The dimension of Y table is:  (25286,)

# %% [markdown]
# ### 2.1 Train/Test Split

# %%
from sklearn.model_selection import train_test_split

#divided into testing and training
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
from sklearn import linear_model
from sklearn.dummy import DummyClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# #### 2.2.1 Stochastic Gradient Descent (SGD):

# %%
sgd_model=SGDClassifier()
sgd_model.fit(x_train,y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=None, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
sgd_model_pred=sgd_model.predict(x_test)
acc_sgd_model=round(sgd_model.score(x_train, y_train)*100,2)
acc_sgd_model
# Out:
# 50.22

# %% [markdown]
# #### 2.2.2 Random Forest:

# %%
rmf_model=RandomForestClassifier()
rmf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rmf_model_pred=rmf_model.predict(x_test)
acc_rmf_model=round(rmf_model.score(x_train, y_train)*100,2)
acc_rmf_model
# Out:
# 99.96

# %% [markdown]
# #### 2.2.3 Logistic Regression

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_reg_pred=log_reg.predict(x_test)
acc_log_reg=round(log_reg.score(x_train,y_train)*100,2)
acc_log_reg
# Out:
# 61.06

# %% [markdown]
# #### 2.2.4 K Nearest Neighbor

# %%
knb_model=KNeighborsClassifier()
knb_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
knb_model_pred=knb_model.predict(x_test)
acc_knb_model=round(knb_model.score(x_train,y_train)*100,2)
acc_knb_model
# Out:
# 85.53

# %% [markdown]
# #### 2.2.5 Linear Support Vector Machine

# %%
svm_model=LinearSVC()
svm_model.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0)

# %%
svm_model_pred=svm_model.predict(x_test)
acc_svm_model=round(svm_model.score(x_train,y_train)*100,2)
acc_svm_model
# Out:
# 55.36

# %% [markdown]
# ### 2.3 Which is the best Model

# %%
results = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest','Stochastic Gradient Decent'],
    'Score': [acc_svm_model, acc_knb_model, acc_log_reg, 
              acc_rmf_model,acc_sgd_model]})
result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                             Model
# Score
# 99.96               Random Forest
# 85.53                         KNN
# 61.06         Logistic Regression
# 55.36     Support Vector Machines
# 50.22  Stochastic Gradient Decent

# %% [markdown]
# As we can see, the Random Forest classifier goes on the first place. But first, let us check, how random-forest performs, when we use cross validation.

# %%
from sklearn.model_selection import cross_val_score
rmf_model = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rmf_model, x_train, y_train, cv=10, scoring = "accuracy")
print("Scores:", scores,'\n')
print("Mean:", scores.mean(),'\n')
print("Standard Deviation:", scores.std())
# Out:
# Scores: [0.99314707 0.98998419 0.99261993 0.99367422 0.99525567 0.99630802
#  0.99578059 0.99208861 0.98892405 0.99261214]
#
# Mean: 0.9930394478408132
#
# Standard Deviation: 0.0022595877615854223

# %% [markdown]
# Evaluate Random Forest using the out-of-bag samples to estimate the generalization accuracy. I will not go into details here about how it works. Just note that out-of-bag estimate is as accurate as using a test set of the same size as the training set. Therefore, using the out-of-bag error estimate removes the need for a set aside test set

# %%
rmf_model = RandomForestClassifier(n_estimators=100, oob_score = True)
rmf_model.fit(x_train, y_train)
y_prediction = rmf_model.predict(x_test)

rmf_model.score(x_train, y_train)

acc_rmf_model = round(rmf_model.score(x_train, y_train) * 100, 2)
print(round(acc_rmf_model,2,), "%")
# Out:
# 100.0 %

# %%
print("oob score:", round(rmf_model.oob_score_, 4)*100, "%")
# Out:
# oob score: 99.33999999999999 %

# %% [markdown]
# ### 2.4 Further Evaluation

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
from sklearn.model_selection import cross_val_predict

predictions = cross_val_predict(rmf_model, x_train, y_train, cv=3)
predictions[:10] # first 10 predictions
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 1, 1])

# %%
confusion_matrix(y_train,predictions)
# Out:
# array([[8892,  103],
#        [  50, 9919]])

# %%
print("Precision_score: ", precision_score(y_train,predictions),'\n')
print("Recall: ", recall_score(y_train,predictions),'\n')
print("Accruacy_score: ", accuracy_score(y_train,predictions),'\n')
print("F_score: ", f1_score(y_train, predictions))
# Out:
# Precision_score:  0.9897226102574337
#
# Recall:  0.9949844518005818
#
# Accruacy_score:  0.9919320818392744
#
# F_score:  0.9923465559501777

# %% [markdown]
# #### Precision Recall Curve

# %%
from sklearn.metrics import precision_recall_curve

# getting the probabilities of our predictions
y_scores = rmf_model.predict_proba(x_train)
y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(y_train, y_scores)
def plot_precision_and_recall(precision, recall, threshold):
    plt.plot(threshold, precision[:-1], "r-", label="precision", linewidth=5)
    plt.plot(threshold, recall[:-1], "b", label="recall", linewidth=5)
    plt.xlabel("threshold", fontsize=19)
    plt.legend(loc="upper right", fontsize=19)
    plt.ylim([0, 1])

plt.figure(figsize=(14, 7))
plot_precision_and_recall(precision, recall, threshold)
plt.show()
